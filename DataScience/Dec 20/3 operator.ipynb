# %%
a = 10
b = 20
print(a + b)
# Out:
# 30

# %%
a - b
# Out:
# -10

# %%
a*b
# Out:
# 200

# %%
b/a
# Out:
# 2.0

# %%
b//a
# Out:
# 2

# %%
b % a
# Out:
# 0

# %%
a**b
# Out:
# 100000000000000000000

# %%
# comparison

# %%
a == b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
a > b
# Out:
# False

# %%
a < b
# Out:
# True

# %%
x = True
y = False

# %%
x and y  #both true
# Out:
# False

# %%
x or y
# Out:
# True

# %%
not x
# Out:
# False

# %%
not y
# Out:
# True

# %%
n = 10

# %%
n += 5 # n = n + 5
print(n)
# Out:
# 15

# %%
n -= 6  # n = n - 6
print(n)
# Out:
# 9

# %%
n *= 5   # n = n * 5
print(n)
# Out:
# 45

# %%
# n = n/5
n /= 5
print(n)
# Out:
# 9.0
