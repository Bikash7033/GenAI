# %% [markdown]
# # take input from the user
#
# x = "akshat"
# print(x)
#
# o/p : akshat
#
#
# x = input("enter the name")
# print(x)
#
#
# o/p
# enter the name : john
# john

# %%
x = input("what is your name")
# Out:
# what is your name john

# %%
print(f"welcome to the training {x}")
# Out:
# welcome to the training john

# %%
y = input("enter your age")
print(y)
# Out:
# enter your age i dont know
# i dont know

# %% [markdown]
# the age need to be in the integer format

# %%
y = int(input("enter your age"))
print(y)
# Out:
# enter your age 12
# 12

# %% [markdown]
# operator precedence
#
# result = 10 + 2 * 3
#
# python uses PEMDAS (parantheses, exponent , multiplication/Division. Addition/Subration)

# %%
result = 10 + 2 * 3
result
# Out:
# 16

# %%
result = (10 + 2) * 3 
result
# Out:
# 36

# %%
result = 2 ** 3 ** 2 # right to left exponentiation
# 2 ** (3 ** 2)
result
# Out:
# 512
