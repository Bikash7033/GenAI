# %%
# We read the data from data3.csv file and update the none or NAN data with 0

# %%
#read the csv file
import pandas as pd
df = pd.read_csv("data3.csv")
print(df)
# Out:
#    Name   Age  Marks
# 0  Amit  25.0   80.0
# 1  Ravi   NaN   90.0
# 2   NaN  30.0    NaN

# %%
#check for the missing values 
df.isnull()
# Out:
#     Name    Age  Marks
# 0  False  False  False
# 1  False   True  False
# 2   True  False   True

# %%
#fill all the missing values with zero 
df_filled = df.fillna("NA")

# %%
print(df_filled)
# Out:
#    Name   Age Marks
# 0  Amit  25.0  80.0
# 1  Ravi    NA  90.0
# 2    NA  30.0    NA

# %%
print(df)
# Out:
#    Name   Age  Marks
# 0  Amit  25.0   80.0
# 1  Ravi   NaN   90.0
# 2   NaN  30.0    NaN

# %%
#modify the data3.csv with the updated filled data

# %%
df_filled.to_csv("cleaneddata.csv")
