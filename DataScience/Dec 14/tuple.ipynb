# %% [markdown]
# Tuple : It is like list but elements are immutable .
# Fast then list
# list = [1, 2, 3]
# tuple = (1, 2, 3)

# %%
my_tuple = (10,20,30,40)
print(my_tuple)
# Out:
# (10, 20, 30, 40)

# %%
print(my_tuple[0])
# Out:
# 10

# %%
print(my_tuple[1])
# Out:
# 20

# %%
x = [1,2,3]
print(x)
x[0] = 30
print(x)
# Out:
# [1, 2, 3]
# [30, 2, 3]

# %%
x = (1,2,3)
print(x)
x[0] = 12
print(x)  # error because tuple elements are immutable
# Out:
# (1, 2, 3)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 x = (1,2,3)
#       2 print(x)
# ----> 3 x[0] = 12
#       4 print(x)
#
# TypeError: 'tuple' object does not support item assignment
