# %%
print("hello world")
# Out:
# hello world

# %%
x = "hello world"
print(x)
# Out:
# hello world

# %%
type(x)
# Out:
# str

# %%
x = str("10")
print(type(x))
# Out:
# <class 'str'>

# %%
y = 10
print(type(y))
# Out:
# <class 'int'>
